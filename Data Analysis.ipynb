# %% [markdown]
# # Data Analysis

# %% [markdown]
# ## Data import from the database

# %%
import sqlite3
import pandas as pd

# %%
conn = sqlite3.connect('Data_job_listings_CV_full.db')

# %%
query = '''
SELECT Job_listings.*, Companies.*, Locations.*
FROM Job_listings
LEFT JOIN Companies ON Job_listings.'Company ID'= Companies.Company_id
LEFT JOIN Locations ON Job_listings.'Location ID' = Locations.location_id
'''

# %%
df = pd.read_sql(query, conn)

# %%
# Convert the 'Published' column to date
df['Published'] = pd.to_datetime(df['Published'], format='%d.%m.%Y')

# %%
df.to_csv('Job postings.csv', index=False)

# %% [markdown]
# ## Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import seaborn as sns
from wordcloud import WordCloud, STOPWORDS

# %% [markdown]
# ### Titles analysis

# %%
# wordcloud - most mentioned words in job descriptions

text = df.Title.tolist()

# defining words we not gonna consider for review:
comment_words = ''
stopwords =['data','datu','analītikis','analītiķis','analyst','e','un','ā','junior','senior','middle','specialist','vecākais'] + list(STOPWORDS)   # zodziai, kuriu neitraukti 

for val in df['Title']:
        val = str(val)     # transform column to single string
        tokens = val.split()       # slpit by word
        for i in range(len(tokens)):       # change all words to lowercase
            tokens[i] = tokens[i].lower() 
     
        comment_words += " ".join(tokens)+" "   # comnbine all words to one string

# Create wordcloud - show 15 most common words 
wordcloud = WordCloud(width = 900, height = 700,
                background_color ='white',
                stopwords = stopwords,
                max_words=15,
                min_font_size = 10).generate(comment_words)

# wordcloud to figure
plt.figure(figsize = (7, 7), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()

# %% [markdown]
# ### Company analysis

# %%
# Most hiring companies
company_count = df['Company name'].value_counts().reset_index().head(5)
company_count.columns = ['Company name', 'Job Count']

plt.subplots(figsize=(11,5))
sns.barplot(data=company_count,x='Job Count',y='Company name',palette='Set2').set(title="Top 5 companies with most open vacancies")
plt.show()

# %% [markdown]
# ### Salary distribution

# %%
df['avg_salary'] = df[['Salary Range min', 'Salary Range max']].mean(axis=1)

# %%
mean_salary = df['avg_salary'].mean()
std_salary = df['avg_salary'].std()

# %%
plt.hist(df['avg_salary'].dropna(), bins=12, alpha=0.5, color='blue')
plt.axvline(mean_salary, color='red', linestyle='dashed', linewidth=1)
plt.title('Salary Distribution')
plt.xlabel('Salary Range')
plt.ylabel('Number of Job Listings')
plt.show()

# %%
# Filter the DataFrame for Latvia and Lithuania
latvia_df = df[df['Country'] == 'Latvia']
lithuania_df = df[df['Country'] == 'Lithuania']

# Calculate the average salary for Latvia and Lithuania
latvia_mean_salary = latvia_df['avg_salary'].mean()
lithuania_mean_salary = lithuania_df['avg_salary'].mean()

# Create a table with salary statistics
stats_table = pd.DataFrame({
    'Country': ['Latvia', 'Lithuania'],
    'Minimum Salary': [latvia_df['avg_salary'].min(), lithuania_df['avg_salary'].min()],
    'Maximum Salary': [latvia_df['avg_salary'].max(), lithuania_df['avg_salary'].max()],
    'Average Salary': [latvia_mean_salary, lithuania_mean_salary],
    'Median Salary': [latvia_df['avg_salary'].median(), lithuania_df['avg_salary'].median()],
    'Standard Deviation': [latvia_df['avg_salary'].std(), lithuania_df['avg_salary'].std()]
})

# Style the table for better formatting
stats_table = stats_table.style.set_table_styles([{
    'selector': 'th',
    'props': [
        ('background-color', 'lightgrey'),
        ('color', 'black'),
        ('font-weight', 'bold'),
        ('text-align', 'center'),
        ('border', '1px solid black'),
        ('padding', '5px')
    ]
}, {
    'selector': 'td',
    'props': [
        ('text-align', 'center'),
        ('border', '1px solid black'),
        ('padding', '5px')
    ]
}])

stats_table

# Format the values in the statistics table
stats_table_formatted = stats_table.format({
    'Minimum Salary': '{:.2f}',
    'Maximum Salary': '{:.2f}',
    'Average Salary': '{:.2f}',
    'Median Salary': '{:.2f}',
    'Standard Deviation': '{:.2f}'
})

# Display the formatted table
stats_table_formatted
# Out:
# <style  type="text/css" >
#     #T_5693d_ th {
#           background-color: lightgrey;
#           color: black;
#           font-weight: bold;
#           text-align: center;
#           border: 1px solid black;
#           padding: 5px;
#     }    #T_5693d_ td {
#           text-align: center;
#           border: 1px solid black;
#           padding: 5px;
#     }</style><table id="T_5693d_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Country</th>        <th class="col_heading level0 col1" >Minimum Salary</th>        <th class="col_heading level0 col2" >Maximum Salary</th>        <th class="col_heading level0 col3" >Average Salary</th>        <th class="col_heading level0 col4" >Median Salary</th>        <th class="col_heading level0 col5" >Standard Deviation</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5693d_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_5693d_row0_col0" class="data row0 col0" >Latvia</td>
#                         <td id="T_5693d_row0_col1" class="data row0 col1" >800.00</td>
#                         <td id="T_5693d_row0_col2" class="data row0 col2" >6150.00</td>
#                         <td id="T_5693d_row0_col3" class="data row0 col3" >2472.28</td>
#                         <td id="T_5693d_row0_col4" class="data row0 col4" >2300.00</td>
#                         <td id="T_5693d_row0_col5" class="data row0 col5" >1006.02</td>
#             </tr>
#             <tr>
#                         <th id="T_5693d_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_5693d_row1_col0" class="data row1 col0" >Lithuania</td>
#                         <td id="T_5693d_row1_col1" class="data row1 col1" >800.00</td>
#                         <td id="T_5693d_row1_col2" class="data row1 col2" >5300.00</td>
#                         <td id="T_5693d_row1_col3" class="data row1 col3" >3356.70</td>
#                         <td id="T_5693d_row1_col4" class="data row1 col4" >3350.00</td>
#                         <td id="T_5693d_row1_col5" class="data row1 col5" >1015.65</td>
#             </tr>
#     </tbody></table>

# %%
# Check job positions with highest starting salary 

highest_pay = df.sort_values('Salary Range min', ascending = False).head(5)

plt.subplots(figsize=(11,5))
sns.barplot(data=highest_pay,x='Salary Range min',y='Title',palette='Set2').set(title="Top 5 vacancies with highest starting salary")
plt.show()

# %%
company_pay = df.sort_values('avg_salary', ascending = False).head(5)

plt.subplots(figsize=(11,5))
sns.barplot(data=company_pay,x='avg_salary',y='Company name',palette='Set2').set(title="Top 5 companies with highest average pay")
plt.show()

# %%
# Filter data for Lithuania and Latvija
df_lithuania = df[(df['Country'] == 'Lithuania')]
df_latvia = df[(df['Country'] == 'Latvia') | (df['Country'] == ' Latvija')]

# Calculate average salaries 
vilnius_avg_salary = df_lithuania['avg_salary'].mean()
riga_avg_salary = df_latvia['avg_salary'].mean()

# Create a bar plot
plt.subplots(figsize=(8, 6))
sns.barplot(x=['Lithuania', 'Latvija'], y=[vilnius_avg_salary, riga_avg_salary])
plt.title('Average Salary Comparison: Lithuania and Latvia')
plt.ylabel('Average Salary')
plt.xlabel('Country')

plt.show()

# %% [markdown]
# ###  Job posting distribution by location

# %%
df_country = df[(df['Country'] == 'Latvia') | (df['Country'] == 'Lithuania')]

# %%
# group the data by city and count the number of jobs in each city
jobs_by_country = df_country.groupby('Country')['Title'].count()

#define Seaborn color palette to use
colors = sns.color_palette('pastel')[0:5]
plt.figure(figsize=(7,7)) # set figure size
#create pie chart
plt.pie(jobs_by_country, labels=jobs_by_country.index, colors = colors, autopct='%1.1f%%', textprops={'fontsize': 14})
plt.tight_layout()
plt.show()

# %%
df_latvia = df[(df['Country'] == 'Latvia') | (df['Country'] == ' Latvija')]

# %%
# group the data by city and count the number of jobs in each city
jobs_by_city = df_latvia.groupby('City')['Title'].count()

#define Seaborn color palette to use
colors = sns.color_palette('pastel')[0:5]
plt.figure(figsize=(7,7)) # set figure size
#create pie chart
plt.pie(jobs_by_city, labels=jobs_by_city.index, colors = colors, autopct='%1.1f%%', textprops={'fontsize': 14})
plt.tight_layout()
plt.show()

# %%
df_lithuania = df[(df['Country'] == 'Lithuania')]

# %%
# group the data by city and count the number of jobs in each city
jobs_by_city = df_lithuania.groupby('City')['Title'].count()

#define Seaborn color palette to use
colors = sns.color_palette('pastel')[0:5]
plt.figure(figsize=(7,7)) # set figure size
#create pie chart
plt.pie(jobs_by_city, labels=jobs_by_city.index, colors = colors, autopct='%1.1f%%', textprops={'fontsize': 14})
plt.tight_layout()
plt.show()

# %% [markdown]
# ###  Publish date

# %%
# Group the data by day and count the number of job postings
job_postings_by_day = df.groupby(df['Published'].dt.date).size()

# Create a line plot
plt.figure(figsize=(12, 6))
job_postings_by_day.plot(kind='line', marker='o')
plt.title('Job Postings by Day')
plt.xlabel('Date')
plt.ylabel('Number of Job Postings')
plt.show()

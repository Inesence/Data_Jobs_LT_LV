# %% [markdown]
# # Analysis of Data Job Market in Latvia and Lithuania
# ## Data Collection and preparation

# %% [markdown]
# ### 0.Setting up Virtual Environment

# %%
# !pip install virtualenv
# !virtualenv myenv
# Out:
# Requirement already satisfied: virtualenv in c:\users\inese_\anaconda3\lib\site-packages (20.23.0)
# Requirement already satisfied: filelock<4,>=3.11 in c:\users\inese_\anaconda3\lib\site-packages (from virtualenv) (3.12.0)
# Requirement already satisfied: platformdirs<4,>=3.2 in c:\users\inese_\anaconda3\lib\site-packages (from virtualenv) (3.5.0)
# Requirement already satisfied: distlib<1,>=0.3.6 in c:\users\inese_\anaconda3\lib\site-packages (from virtualenv) (0.3.6)
# created virtual environment CPython3.8.8.final.0-64 in 2293ms
#   creator CPython3Windows(dest=C:\Users\Inese_\Desktop\sgt_project2\myenv, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, setuptools=bundle, wheel=bundle, via=copy, app_data_dir=C:\Users\Inese_\AppData\Local\pypa\virtualenv)
#     added seed packages: pip==23.1.2, setuptools==67.7.2, wheel==0.40.0
#   activators BashActivator,BatchActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator

# %%
# !myenv\Scripts\activate.bat

# %% [markdown]
# ### 1. Data Collection

# %%
import requests
from bs4 import BeautifulSoup

# %%
import pandas as pd

# %%
import re

# %% [markdown]
# ### Latvian cv.lv

# %%
url = 'https://www.cv.lv/lv/search?limit=2000&offset=20&keywords%5B0%5D=data%20analyst&keywords%5B1%5D=data%20scientist&keywords%5B2%5D=data%20engineer&keywords%5B3%5D=machine%20learning&keywords%5B4%5D=analyst&keywords%5B5%5D=anal%C4%ABti%C4%B7is&keywords%5B6%5D=datu&keywords%5B7%5D=datu%20zin%C4%81tnieks&keywords%5B8%5D=big%20data%20analytics&sorting=EXPIRING&fuzzy=false&suitableForRefugees=false&isHourlySalary=false&isRemoteWork=false&isQuickApply=false'
response = requests.get(url)

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
vacancy_items = soup.find_all("li", class_="jsx-1871295890 jsx-2661613696 vacancies-list__item false")

# %%
vacancies = []
for item in vacancy_items:
    title = item.find("span", class_="jsx-1401030249 vacancy-item__title").text.strip()
    vacancy_item = item.find('a', {'class': 'vacancy-item'})
    vacancy_url = vacancy_item.get('href')
    end_date = item.find("span", class_="jsx-1401030249 vacancy-item__expiry").text.strip()
                                
    location = item.find("span", class_="jsx-1401030249 vacancy-item__locations").text.strip()
    salary = item.find("span", class_="jsx-1401030249 vacancy-item__salary-label")
    if salary is not None:
        salary = salary.text.strip()
    
    info_secondary = item.find('div', {'class': 'vacancy-item__info-secondary'})
    info_secondary_text = info_secondary.get_text()
    
    time_patterns = '(dien(a|s)|stund(a|s)|mēne(ši|sis)|sekund(e|es)|minūt(es|e))'
    pattern = f'Publicēts pirms (\d+) {time_patterns}|Atjaunināts pirms (\d+) {time_patterns}'
    match = re.search(pattern, info_secondary_text)
    published = match.group(0)
    
    p=1
    for a_tag in item.find_all('a', {'class': 'jsx-1401030249'}):
        p=p+1
        if p==3:
            company_name = a_tag.text
            company_url = a_tag['href']
        
      
    vacancies.append({
        "Title": title,
        "Vacancy URL" : vacancy_url,
        "Company name": company_name,
        "Company URL" :company_url,
        "Location": location,
        "Published": published,
        "End_date" : end_date, 
        "Salary": salary
    })

df = pd.DataFrame(vacancies)

# %% [markdown]
# ### Lithuanian cv.lt

# %%
vacancies_lt = []

for page in range(1, 10): # Change the range according to the number of pages you want to scrape
    url_lt = f"https://www.cv.lt/darbo-paieska/data?page={page}&texts=data"
    response = requests.get(url_lt)
    soup = BeautifulSoup(response.content, "html.parser")
    vacancy_items = soup.select(".job-wr")

    for item in vacancy_items:
        title = item.find("button", class_="title").text.strip()
        vacancy_item= soup.select_one('.job-wr')
        vacancy_url = vacancy_item['href']
        company_name = item.find("span", {"class": "company"}).find("button").text.strip()

        # for Lithuanian website, company url is not available, adding for merging purposes
        company_url = "NaN"

        location = item.find("span", {"class": "company"}).find("span").text.strip()
        published = item.select_one(".time span").text

        # for Lithuanian website, expiry date is not available, adding for merging purposes
        end_date = "NaN"

        salary = item.find("span", {"class": "salary"})
        if salary is not None:
            salary = salary.text.strip()
        else:
            salary='NaN'

        vacancies_lt.append({
                "Title": title,
                "Vacancy URL": vacancy_url,
                "Company name": company_name,
                "Company URL": company_url,
                "Location": location,
                "Published": published,
                "End_date": end_date,
                "Salary": salary,
            })

df_lt = pd.DataFrame(vacancies_lt)

# %% [markdown]
# ### 3. Data Cleaning

# %% [markdown]
# ### cv.lv

# %%
cv_lv_link = r'https://www.cv.lv'
df['Vacancy URL'] = cv_lv_link + df['Vacancy URL']
df['Company URL'] = cv_lv_link + df['Company URL']

# %%
df['End_date'] = df['End_date'].str.replace('Beidzas: ', '')

# %%
df['Location'] = df['Location'].str.replace('—', '')
# split Location column into City, Region, Country
splitting = lambda x: pd.Series([i for i in reversed(x.split(','))])
df[['Country', 'Region', 'City']] = df['Location'].apply(splitting)

# Remove the original Location column
df.drop('Location', axis=1, inplace=True)

# %%
df
# Out:
#                                                  Title  \
# 0    Izglītības departamenta direktora vietnieks iz...
# 1        Junior Project Manager for eCommerce projects
# 2                             Mid-level CRO Strategist
# 3                        LOĢISTIKAS SPECIĀLISTA PALĪGS
# 4    VADOŠAIS IT ADMINISTRATORS/-E INFORMĀCIJAS TEH...
# ..                                                 ...
# 994                                      Test Engineer
# 995                               Senior Test Engineer
# 996                                   Security Manager
# 997  Automatizācijas sistēmu inženieris/ Vadošais a...
# 998  Projektu vadītājs Zinātniskā institūta Izglītī...
#
#                                            Vacancy URL  \
# 0    https://www.cv.lv/lv/vacancy/998347/lr-izgliti...
# 1    https://www.cv.lv/lv/vacancy/986154/scandiweb/...
# 2    https://www.cv.lv/lv/vacancy/986162/scandiweb/...
# 3    https://www.cv.lv/lv/vacancy/986401/konig-dist...
# 4    https://www.cv.lv/lv/vacancy/985999/bluor-bank...
# ..                                                 ...
# 994  https://www.cv.lv/lv/vacancy/993940/visma/test...
# 995  https://www.cv.lv/lv/vacancy/995138/visma/seni...
# 996  https://www.cv.lv/lv/vacancy/987624/visma/secu...
# 997  https://www.cv.lv/lv/vacancy/992319/belam-riga...
# 998  https://www.cv.lv/lv/vacancy/926371/paula-stra...
#
#                                        Company name  \
# 0              LR Izglītības un zinātnes ministrija
# 1                                         scandiweb
# 2                                         scandiweb
# 3                             König Distribution AS
# 4                                     BluOr Bank AS
# ..                                              ...
# 994                                           VISMA
# 995                                           VISMA
# 996                                           VISMA
# 997                                Belam - Riga SIA
# 998  Paula Stradiņa Klīniskā universitātes slimnīca
#
#                                            Company URL  \
# 0    https://www.cv.lv/lv/search/employer/lr-izglit...
# 1    https://www.cv.lv/lv/search/employer/scandiweb...
# 2    https://www.cv.lv/lv/search/employer/scandiweb...
# 3    https://www.cv.lv/lv/search/employer/konig-dis...
# 4    https://www.cv.lv/lv/search/employer/bluor-ban...
# ..                                                 ...
# 994  https://www.cv.lv/lv/search/employer/visma?emp...
# 995  https://www.cv.lv/lv/search/employer/visma?emp...
# 996  https://www.cv.lv/lv/search/employer/visma?emp...
# 997  https://www.cv.lv/lv/search/employer/belam-rig...
# 998  https://www.cv.lv/lv/search/employer/paula-str...
#
#                        Published    End_date         Salary   Country  \
# 0        Publicēts pirms 5 diena  17.05.2023  € 2425 – 2695   Latvija
# 1      Atjaunināts pirms 1 diena  17.05.2023   € 800 – 1350   Latvija
# 2      Atjaunināts pirms 1 diena  17.05.2023  € 2000 – 3000   Latvija
# 3     Atjaunināts pirms 6 stunda  17.05.2023         € 1300   Latvija
# 4    Atjaunināts pirms 7 minūtes  17.05.2023  € 3500 – 4000   Latvija
# ..                           ...         ...            ...       ...
# 994     Publicēts pirms 13 diena  30.06.2023  € 2000 – 3000   Latvija
# 995     Publicēts pirms 11 diena  30.06.2023  € 2400 – 3000   Latvija
# 996     Publicēts pirms 27 diena  30.06.2023  € 3500 – 4500   Latvija
# 997    Atjaunināts pirms 5 diena  27.07.2023         € 2000   Latvija
# 998     Publicēts pirms 5 mēneši  21.12.2023         € 1350   Latvija
#
#             Region   City
# 0     Rīgas rajons   Rīga
# 1     Rīgas rajons   Rīga
# 2     Rīgas rajons   Rīga
# 3     Rīgas rajons   Rīga
# 4     Rīgas rajons   Rīga
# ..             ...    ...
# 994   Rīgas rajons   Rīga
# 995   Rīgas rajons   Rīga
# 996   Rīgas rajons   Rīga
# 997   Rīgas rajons   Rīga
# 998   Rīgas rajons   Rīga
#
# [999 rows x 10 columns]

# %%
# Remove the euro sign
df['Salary'] = df['Salary'].str.replace('€', '').str.strip()


# Check the format of each entry and apply the corresponding operation
df[['Salary Range min', 'Salary Range max']] = df['Salary'].str.split('–', n=1, expand=True)

# %%
df['Salary Range min'] = df['Salary Range min'].str.replace('/st.', '').str.strip().astype(float)
df['Salary Range max'] = df['Salary Range max'].str.replace('/st.', '').str.strip().astype(float)
# Out:
# <ipython-input-16-ca21c0923506>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Salary Range min'] = df['Salary Range min'].str.replace('/st.', '').str.strip().astype(float)
# <ipython-input-16-ca21c0923506>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Salary Range max'] = df['Salary Range max'].str.replace('/st.', '').str.strip().astype(float)

# %%
for i in df.index:
    if pd.notna(df['Salary'][i]) and isinstance(df['Salary'][i], str) and '/st.' in df['Salary'][i]:
        if pd.notna(df['Salary Range min'][i]) and pd.notna(df['Salary Range max'][i]):
            df.loc[i, ['Salary Range min', 'Salary Range max']] *= 21.62 * 8

# %%
# Round the values to 2 decimal places
df['Salary Range min'] = df['Salary Range min'].round(2)
df['Salary Range max'] = df['Salary Range max'].round(2)

# %%
# remove the original Salary column
df.drop('Salary', axis=1, inplace=True)

# %%
import re
from datetime import datetime, timedelta

def get_date_from_string(s):
    if "dien" in s:
        days_ago = int(re.search(r'\d+', s).group())
        return (datetime.now() - timedelta(days=days_ago)).strftime('%d.%m.%Y')
    elif "mēnesi" in s:
        months_ago = int(re.search(r'\d+', s).group())
        return (datetime.now() - timedelta(days=months_ago*30)).strftime('%d.%m.%Y')
    elif "seku" in s or "min" in s or "stund" in s:
        return datetime.now().strftime('%d.%m.%Y')

# Apply the function to the column 'Published'
df['Published'] = df['Published'].apply(get_date_from_string)

# %% [markdown]
# ### cv.lt

# %%
# Adding beginning for vacancy url to show full link
cv_lt_link = r'https://www.cv.lt'
df_lt['Vacancy URL'] = cv_lt_link + df_lt['Vacancy URL']

# %%
# split Location field, if more than one city- to show as 'Various'
df_lt['Location'] = df_lt['Location'].apply(lambda x: 'Various' if isinstance(x, str) and ',' in x else x)

# %%
# Replace Location field 'Kitas' to 'Other' 
df_lt['Location'] = df_lt['Location'].str.replace('Kitas', 'Other').str.strip()

# %%
# Adding columns to match LV formating for location

Country='Lithuania'
df_lt.insert(loc=df_lt.columns.get_loc('End_date') + 2, column='Country', value=Country)
df_lt.insert(loc=df_lt.columns.get_loc('End_date')+3,column='Region', value='Nan')
df_lt.insert(loc=df_lt.columns.get_loc('End_date')+4,column='City', value=df_lt['Location'])


# Remove the original Location column
df_lt.drop('Location', axis=1, inplace=True)

# %%
# Cleaning Salary field, if it is showing different value than salary amount, to remove and show it as 0
def clean_salary(salary):
    if salary.startswith("Pareiginės "):
        return 'NaN'
    else:
        return salary
    
df_lt["Salary"] = df_lt["Salary"].apply(clean_salary)

# %%
# Remove the euro sign 
df_lt['Salary'] = df_lt['Salary'].str.replace('€', '').str.strip()

# Remove the 'Nuo..' word
df_lt['Salary'] = df_lt['Salary'].str.replace('Nuo', '').str.strip()

# Remove the dot as a thousands separator
df_lt['Salary'] = df_lt['Salary'].str.replace('.', '').str.strip()
# Out:
# <ipython-input-26-3ce97d3e2b69>:8: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df_lt['Salary'] = df_lt['Salary'].str.replace('.', '').str.strip()

# %%
# Spliting Salary field into two columns
df_lt[['Salary Range min', 'Salary Range max']] = df_lt['Salary'].str.extract(r'^(.*?)(?:-(.*))?$')

# %%
df_lt['Salary Range min'] = df_lt['Salary Range min'].str.replace('/st.', '').str.strip().astype(float)
df_lt['Salary Range max'] = df_lt['Salary Range max'].str.replace('/st.', '').str.strip().astype(float)
# Out:
# <ipython-input-28-e7b833d569b4>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_lt['Salary Range min'] = df_lt['Salary Range min'].str.replace('/st.', '').str.strip().astype(float)
# <ipython-input-28-e7b833d569b4>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_lt['Salary Range max'] = df_lt['Salary Range max'].str.replace('/st.', '').str.strip().astype(float)

# %%
# Round the values to 2 decimal places
df_lt['Salary Range min'] = df_lt['Salary Range min'].round(2)
df_lt['Salary Range max'] = df_lt['Salary Range max'].round(2)

# %%
# remove the original Salary column
df_lt.drop('Salary', axis=1, inplace=True)

# %%
# Formating job posting to show date instead of 'Before X days/months' etc.

import re
from datetime import datetime, timedelta

def get_date_from_string(s):
    if "d." in s:
        days_ago = int(re.search(r'\d+', s).group())
        return (datetime.now() - timedelta(days=days_ago)).strftime('%d.%m.%Y')
    elif "mėn." in s:
        months_ago = int(re.search(r'\d+', s).group())
        return (datetime.now() - timedelta(days=months_ago*30)).strftime('%d.%m.%Y')
    elif "val." in s or "min" in s:
        return datetime.now().strftime('%d.%m.%Y')

# Apply the function to the column 'Published'
df_lt['Published'] = df_lt['Published'].apply(get_date_from_string)

# %%
# Merging both dataframes into one
full_df = pd.concat([df, df_lt], ignore_index=True)

# %%
full_df
# Out:
#                                                   Title  \
# 0     Izglītības departamenta direktora vietnieks iz...
# 1         Junior Project Manager for eCommerce projects
# 2                              Mid-level CRO Strategist
# 3                         LOĢISTIKAS SPECIĀLISTA PALĪGS
# 4     VADOŠAIS IT ADMINISTRATORS/-E INFORMĀCIJAS TEH...
# ...                                                 ...
# 1174  Finansų politikos departamento Fiskalinės vald...
# 1175  Administracijos direktoriaus patarėjas (pareig...
# 1176                            Ugdymo skyriaus vedėjas
# 1177         Plungės miesto seniūnija seniūno padėjėjas
# 1178  Personalo administravimo skyriaus vyriausiasis...
#
#                                             Vacancy URL  \
# 0     https://www.cv.lv/lv/vacancy/998347/lr-izgliti...
# 1     https://www.cv.lv/lv/vacancy/986154/scandiweb/...
# 2     https://www.cv.lv/lv/vacancy/986162/scandiweb/...
# 3     https://www.cv.lv/lv/vacancy/986401/konig-dist...
# 4     https://www.cv.lv/lv/vacancy/985999/bluor-bank...
# ...                                                 ...
# 1174  https://www.cv.lt/valstybes-tarnyba/resocializ...
# 1175  https://www.cv.lt/valstybes-tarnyba/resocializ...
# 1176  https://www.cv.lt/valstybes-tarnyba/resocializ...
# 1177  https://www.cv.lt/valstybes-tarnyba/resocializ...
# 1178  https://www.cv.lt/valstybes-tarnyba/resocializ...
#
#                                            Company name  \
# 0                  LR Izglītības un zinātnes ministrija
# 1                                             scandiweb
# 2                                             scandiweb
# 3                                 König Distribution AS
# 4                                         BluOr Bank AS
# ...                                                 ...
# 1174           Lietuvos Respublikos finansų ministerija
# 1175                           Lietuvos kultūros taryba
# 1176                  Šiaulių Juliaus Janonio gimnazija
# 1177         Plungės rajono savivaldybės administracija
# 1178  Policijos departamentas prie Lietuvos Respubli...
#
#                                             Company URL   Published  \
# 0     https://www.cv.lv/lv/search/employer/lr-izglit...  11.05.2023
# 1     https://www.cv.lv/lv/search/employer/scandiweb...  15.05.2023
# 2     https://www.cv.lv/lv/search/employer/scandiweb...  15.05.2023
# 3     https://www.cv.lv/lv/search/employer/konig-dis...  16.05.2023
# 4     https://www.cv.lv/lv/search/employer/bluor-ban...  16.05.2023
# ...                                                 ...         ...
# 1174                                                NaN  08.05.2023
# 1175                                                NaN  05.05.2023
# 1176                                                NaN  09.05.2023
# 1177                                                NaN  11.05.2023
# 1178                                                NaN  13.05.2023
#
#         End_date    Country         Region      City  Salary Range min  \
# 0     17.05.2023    Latvija   Rīgas rajons      Rīga            2425.0
# 1     17.05.2023    Latvija   Rīgas rajons      Rīga             800.0
# 2     17.05.2023    Latvija   Rīgas rajons      Rīga            2000.0
# 3     17.05.2023    Latvija   Rīgas rajons      Rīga            1300.0
# 4     17.05.2023    Latvija   Rīgas rajons      Rīga            3500.0
# ...          ...        ...            ...       ...               ...
# 1174         NaN  Lithuania            Nan   Vilnius               NaN
# 1175         NaN  Lithuania            Nan   Vilnius               NaN
# 1176         NaN  Lithuania            Nan  Šiauliai               NaN
# 1177         NaN  Lithuania            Nan    Plungė               NaN
# 1178         NaN  Lithuania            Nan   Vilnius               NaN
#
#       Salary Range max
# 0               2695.0
# 1               1350.0
# 2               3000.0
# 3                  NaN
# 4               4000.0
# ...                ...
# 1174               NaN
# 1175               NaN
# 1176               NaN
# 1177               NaN
# 1178               NaN
#
# [1179 rows x 11 columns]

# %% [markdown]
# ### 4. Data Filtering

# %%
filtered_df = full_df[full_df['Title'].str.contains('anal|dat|duom', case=False)]

# %%
filtered_df
# Out:
#                                                   Title  \
# 9                       Middle+/Senior Business Analyst
# 17    Partner Performance Analyst (for a fixed perio...
# 21                                 Junior Web Analytics
# 23    ANALĪTIĶIS/-E Maksājumu pakalpojumu sniedzēju ...
# 27                                        Data Engineer
# ...                                                 ...
# 1111    Business Analyst in Capital Exposure Management
# 1112    Business Analyst in Capital Exposure Management
# 1158  Viešųjų finansų sistemos valdymo grupės finans...
# 1167  Ekonominės analizės skyriaus vyriausiasis spec...
# 1174  Finansų politikos departamento Fiskalinės vald...
#
#                                             Vacancy URL  \
# 9     https://www.cv.lv/lv/vacancy/986697/dataart-lt...
# 17    https://www.cv.lv/lv/vacancy/994377/tele2-sia/...
# 21    https://www.cv.lv/lv/vacancy/986160/scandiweb/...
# 23    https://www.cv.lv/lv/vacancy/986243/rietumu-ba...
# 27    https://www.cv.lv/lv/vacancy/986233/epic-frog/...
# ...                                                 ...
# 1111  https://www.cv.lt/administravimo-darbai/admini...
# 1112  https://www.cv.lt/administravimo-darbai/admini...
# 1158  https://www.cv.lt/teises-darbai/teises-persona...
# 1167  https://www.cv.lt/valstybes-tarnyba/resocializ...
# 1174  https://www.cv.lt/valstybes-tarnyba/resocializ...
#
#                                    Company name  \
# 9                                   DataArt Ltd
# 17                                    Tele2 SIA
# 21                                    scandiweb
# 23                             Rietumu Banka AS
# 27                                    Epic Frog
# ...                                         ...
# 1111          Danske Bank A/S Lietuvos filialas
# 1112          Danske Bank A/S Lietuvos filialas
# 1158   Lietuvos Respublikos finansų ministerija
# 1167  Valstybinė energetikos reguliavimo taryba
# 1174   Lietuvos Respublikos finansų ministerija
#
#                                             Company URL   Published  \
# 9     https://www.cv.lv/lv/search/employer/dataart-l...  18.04.2023
# 17    https://www.cv.lv/lv/search/employer/tele2-sia...  10.05.2023
# 21    https://www.cv.lv/lv/search/employer/scandiweb...  15.05.2023
# 23    https://www.cv.lv/lv/search/employer/rietumu-b...  15.05.2023
# 27    https://www.cv.lv/lv/search/employer/epic-frog...  16.05.2023
# ...                                                 ...         ...
# 1111                                                NaN  08.05.2023
# 1112                                                NaN  05.05.2023
# 1158                                                NaN  11.05.2023
# 1167                                                NaN  13.05.2023
# 1174                                                NaN  08.05.2023
#
#         End_date    Country         Region     City  Salary Range min  \
# 9     17.05.2023    Latvija   Rīgas rajons     Rīga            3500.0
# 17    17.05.2023    Latvija   Rīgas rajons     Rīga            2000.0
# 21    17.05.2023    Latvija   Rīgas rajons     Rīga            1200.0
# 23    17.05.2023    Latvija   Rīgas rajons     Rīga            1500.0
# 27    17.05.2023    Latvija   Rīgas rajons     Rīga            2845.0
# ...          ...        ...            ...      ...               ...
# 1111         NaN  Lithuania            Nan  Vilnius            2680.0
# 1112         NaN  Lithuania            Nan  Vilnius            2680.0
# 1158         NaN  Lithuania            Nan  Vilnius               NaN
# 1167         NaN  Lithuania            Nan    Other               NaN
# 1174         NaN  Lithuania            Nan  Vilnius               NaN
#
#       Salary Range max
# 9               4000.0
# 17                 NaN
# 21              1800.0
# 23              2200.0
# 27              4300.0
# ...                ...
# 1111            4020.0
# 1112            4020.0
# 1158               NaN
# 1167               NaN
# 1174               NaN
#
# [197 rows x 11 columns]

# %%
salary_df = filtered_df[filtered_df['Salary Range min'] < 800]
salary_df
# Out:
#                                                  Title  \
# 278  LEKTORS/-E studiju kursam Digitāla mārketinga ...
# 319                           DATU IEVADES OPERATORS/E
# 384  ĶĪMIĶIS – ANALĪTIĶIS kvalitātes kontroles labo...
# 408                                         ANALĪTIĶIS
#
#                                            Vacancy URL  \
# 278  https://www.cv.lv/lv/vacancy/997487/alberta-ko...
# 319  https://www.cv.lv/lv/vacancy/990469/kronospan-...
# 384  https://www.cv.lv/lv/vacancy/990892/pharmidea-...
# 408  https://www.cv.lv/lv/vacancy/997279/latvijas-v...
#
#                                           Company name  \
# 278                                ALBERTA KOLEDŽA SIA
# 319                                 KRONOSPAN Riga SIA
# 384                                      PHARMIDEA SIA
# 408  Latvijas Vides, ģeoloģijas un meteoroloģijas c...
#
#                                            Company URL   Published  \
# 278  https://www.cv.lv/lv/search/employer/alberta-k...  10.05.2023
# 319  https://www.cv.lv/lv/search/employer/kronospan...  25.04.2023
# 384  https://www.cv.lv/lv/search/employer/pharmidea...  09.05.2023
# 408  https://www.cv.lv/lv/search/employer/latvijas-...  09.05.2023
#
#        End_date   Country         Region     City  Salary Range min  \
# 278  24.05.2023   Latvija   Rīgas rajons     Rīga             10.00
# 319  25.05.2023   Latvija   Rīgas rajons     Rīga              5.50
# 384  26.05.2023   Latvija   Rīgas rajons   Olaine              8.44
# 408  26.05.2023   Latvija   Rīgas rajons     Rīga            700.00
#
#      Salary Range max
# 278               NaN
# 319               NaN
# 384               NaN
# 408             900.0

# %% [markdown]
# ### 5. SQLite Database

# %%
import sqlite3
import pandas as pd

# create a connection and cursor to the database
conn = sqlite3.connect('Job_postings_CV.db')
cursor = conn.cursor()

# create all data table and later update it with new values 
cursor.execute("SELECT name FROM sqlite_master WHERE type='table' AND name='alldata'")
table_exists = cursor.fetchone()

if table_exists:
     # if 'alldata' table already exists, retrieve existing records to show what records already saved
    existing_records = pd.read_sql_query("SELECT * FROM alldata", conn)
    
    # add all data from filtered_df
    updated_df = pd.concat([existing_records, filtered_df])

    # drop duplicates based on all columns
    updated_df = updated_df.drop_duplicates()

    # update the 'alldata' table with the updated dataframe
    updated_df.to_sql('alldata', conn, if_exists='replace', index=False)
else:
    # if the 'alldata' table does not exist, create it
    filtered_df.to_sql('alldata', conn, index=False)

# close cursor and connection
cursor.close()
conn.close()
# Out:
# C:\Users\Inese_\anaconda3\lib\site-packages\pandas\core\generic.py:2779: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   sql.to_sql(

# %%
# Connect to the database
conn = sqlite3.connect('Job_postings_CV.db')
c = conn.cursor()

# Define the value(s) to match
values_to_match = ('LEKTORS/-E studiju kursam Digitāla mārketinga analīze ar Google analytics, Google data studio','Datu ievades operators/-e', 'Ūdensapgādes un kanalizācijas sistēmu inženieris ', 'Construction Manager in the Netherlands (DATA/data center)', 'Compliance and Data Protection Officer', 'DATU IEVADES OPERATORS/E')

# Construct the SQL query
query = f"DELETE FROM alldata WHERE Title IN {values_to_match} "

# Execute the query
c.execute(query)

# Define the substring to match
substring = 'ĶĪM'  

# Create the query
query = "DELETE FROM alldata WHERE Title LIKE '%' || ? || '%'"

# Execute the query
conn.execute(query, (substring,))



# Commit the changes and close the connection
conn.commit()
conn.close()

# %%
import sqlite3

# Connect to the SQLite database
conn = sqlite3.connect('Job_postings_CV.db')
c = conn.cursor()

# Execute the SQL query to update the values
c.execute("UPDATE alldata SET Country = 'Latvia' WHERE Country = '\xa0Latvija' OR Country = ' Latvija'")
# Execute the SQL query to update the values
c.execute("UPDATE alldata SET Country = 'Lithuania' WHERE Country = '\xa0Lietuva'")

# Commit the changes
conn.commit()

# Close the connection
conn.close()
